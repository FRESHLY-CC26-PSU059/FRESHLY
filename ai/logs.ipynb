# %% [markdown]
# # Log keseluruhan Train % Validation

# %%
# %load_ext tensorboard
# %tensorboard --logdir logs --port 6005
# Out:
# The tensorboard extension is already loaded. To reload it, use:
#   %reload_ext tensorboard
#       <iframe id="tensorboard-frame-e35950ee91365439" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-e35950ee91365439");
#           const url = new URL("/", window.location);
#           const port = 6005;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>
